# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd 
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions as expected_conditions

class CheckList():
    def __init__(self, gsNumList):
        # 변수 입력 받기
        gsNumIndex = gsNumList.split('-')
        print(gsNumIndex)
        gsFrame = pd.DataFrame()
        gsFrame['인증번호'] = gsNumIndex
        gsFrame['저작권 확인서'] = ''
        gsFrame['프로그램 등록부'] = ''
        

        # 2, 3 리스트 선언
        jjlist = []
        prolist = []

        
        time.sleep(1.5)
        self.Center(gsNumIndex)
        


    # def centerA(self):
        


    # # 지점별 함수
    def Center(self, gsNumIndex):

        # A 지점 
        for i in range(0, len(gsNumIndex)):
            block = gsNumIndex[i].split('-')

            


    #     # B,C 지점






    # # 체크 함수


    # def Check(self):
    #     time.sleep(2)
    #     print(gsNumIndex[a])
    #     driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()
    #     time.sleep(1)
    #     driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
    #     time.sleep(1)
    #     driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
    #     time.sleep(1)
    #     driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
    #     time.sleep(1.5)
    #     try:
    #         if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
    #             print("확인서 및 등록증이 존재하지 않습니다.")
    #             jjlist.insert(a,'x')
    #             prolist.insert(a,'x')
    #             print(jjlist)
    #             print(prolist)
                
    #     except:
           
    #             print("확인서 및 등록증이 존재합니다.")
    #             jjlist.insert(a,'o')
    #             prolist.insert(a,'o')
    #             print(jjlist)
    #             print(prolist)
                
    #     driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()


    
        


if __name__=="__main__":
    gsNumList = input()

    chrome_options = Options()
    chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
    driver = webdriver.Chrome(options=chrome_options)
    driver.get('http://210.104.181.10/')
    test = CheckList(gsNumList)


    
    driver.get('http://210.96.71.85/main/main.do')
    # 로그인 페이지가 뜰 때까지 대기
    wait = WebDriverWait(driver, 15)
    element = wait.until(expected_conditions.element_to_be_clickable((By.ID, "wrap")))

    driver.find_element(By.NAME, 'user_id').send_keys('manager')
    driver.find_element(By.NAME, 'password').send_keys('manager123')
    driver.find_element(By.XPATH, '//*[@id="form-login"]/div[2]').click()
# Out:
# ['GS', 'A', '23', '102']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\이건우\Desktop\메신저&구글\python_learn\Jupitor\subTest.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a> if __name__=="__main__":
#     <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=99'>100</a>     gsNumList = input()
# --> <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=100'>101</a>     test = CheckList(gsNumList)
#
# c:\Users\이건우\Desktop\메신저&구글\python_learn\Jupitor\subTest.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> driver.get('http://210.104.181.10/')
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> time.sleep(1.5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> self.Center(gsNumIndex)
#
# c:\Users\이건우\Desktop\메신저&구글\python_learn\Jupitor\subTest.ipynb Cell 1 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=40'>41</a> for i in range(0, len(gsNumIndex)):
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=41'>42</a>     block = gsNumIndex[i].split('-')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a> self.driver.get('http://210.96.71.85/main/main.do')
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=46'>47</a> # 로그인 페이지가 뜰 때까지 대기
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%9D%B4%EA%B1%B4%EC%9A%B0/Desktop/%EB%A9%94%EC%8B%A0%EC%A0%80%26%EA%B5%AC%EA%B8%80/python_learn/Jupitor/subTest.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a> wait = WebDriverWait(self.driver, 15)
#
# AttributeError: 'CheckList' object has no attribute 'driver'

# %% [markdown]
# # Rafactoring
#
#  - 기존 순서
# 1-1. 변수 입력
# 1-2. 데이터 프레임에 저장 및 row 생성, 2,3열에 대한 리스트 선언
#
# 2-1. 브라우저 오픈
#
#
# 3-1. A,B,C에 대한 각각의 for문 시작
#
#
# 1. 센터별 for문 객체화
# 2. if문 객체화

# %%
import pandas as pd

gsNumList = input()
gsNumIndex = gsNumList.split()

# gsNum을 result_df 데이터프레임에 저장
gsFrame = pd.DataFrame()
gsFrame['인증번호'] = gsNumIndex

# 나중에 변수 넣기
gsFrame['저작권 확인서'] = ''
gsFrame['프로그램 등록부'] = ''


display(gsFrame)


# gsFrame.to_excel(r"/Users/geon-woo/Desktop/python_learn/GSexcel.xlsx", index=False)
# Out:
#           인증번호 저작권 확인서 프로그램 등록부
# 0  GS-C-23-037
# 1  GS-C-23-048
# 2  GS-C-23-050
# 3  GS-B-23-023
# 4  GS-C-23-047
# 5  GS-B-23-081

# %% [markdown]
# 순서
#
# 1. 첫번째 입력 : (weekly, monthly, 그 외 예외처리)
# 2. 두번째 입력 : gsNum 입력
# 3. gsNum을 result_df 데이터프레임에 저장
# 4. 분당ECM 브라우저 오픈
# 5. --for 선언--
#     gsNum[i]값을 가져와서 '-' 기준으로 split하여 배열(gsSp[3])로 나눔.
#     [1],[2],[3] 값을 case문을 사용하여 상황에 맞게 클릭할 값을 설정.
#     case1 : [1]==B or C 이면 index++하고 break.
#     case2 : [2]==22 이면 '2022 시험서비스' 클릭 후 case4로 이동
#     case3 : [2]==23 이면 '2023 시험서비스' 클릭 후 case4로 이동
#     case4 : 'GS시험인증(1등급)'을 포함하는 텍스트 버튼을 클릭
#             최초 입력한 gsNum[i]값을 포함하는 텍스트 버튼을 클릭
#             '인증관련'을 포함하는 텍스트 버튼을 클릭
#             화면 상에 '등록부' 혹은 '등록증'을 포함하는 텍스트 존재여부에 따라 progRegis[i]에 o,x입력
#             화면 상에 '확인서'를 포함하는 텍스트 존재여부에 따라 copyConfirm[i]에 o,x입력
#             화면 새로고침
# 6. result_df에 progRegis, copyConfirm를 추가
# 7. result_df를 엑셀로 저장

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import time
import pandas as pd

# gsNum 입력
gsNumList = input()
gsNumIndex = gsNumList.split()

# gsNum을 result_df 데이터프레임에 저장
gsFrame = pd.DataFrame()
gsFrame['인증번호'] = gsNumIndex

# 나중에 변수 넣기
gsFrame['저작권 확인서'] = ''
gsFrame['프로그램 등록부'] = ''



# 분당ECM 브라우저 오픈
chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
driver = webdriver.Chrome(options=chrome_options)
driver.get('http://210.104.181.10/')
time.sleep(1.5)

# --for 선언--
for a in range(0, len(gsNumIndex)):

    # gsNum[i]값을 가져와서 '-' 기준으로 split하여 배열(gsSp[3])로 나눔.
    block = gsNumIndex[a].split('-')


    if(block[1]=="A"):
        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                
        except:
            # elif (driver.find_element(By.CLASS_NAME, "//*[contains(text(),'" + "ellipsis" + "')]").is_displayed()):
                print("확인서 및 등록증이 존재합니다.")
                
    
        # driver.get('http://210.104.181.10/')
        # driver.switch_to.default_content()
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()
# Out:
#           인증번호 저작권 확인서 프로그램 등록부
# 0  GS-A-23-079
# 1  GS-A-23-180
# 2  GS-A-23-349
# 3  GS-A-22-510
# 4  GS-A-23-130

# %%
# gsNum을 result_df 데이터프레임에 저장
gsFrame = pd.DataFrame()
gsFrame['인증번호'] = gsNumIndex

# 나중에 변수 넣기
gsFrame['저작권 확인서'] = ''
gsFrame['프로그램 등록부'] = ''



# 분당ECM 브라우저 오픈
chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
driver = webdriver.Chrome(options=chrome_options)
driver.get('http://210.104.181.10/')
time.sleep(1.5)

jjlist = []
prolist = []

# 분당 --for 선언--
for a in range(0, len(gsNumIndex)):

    # gsNum[i]값을 가져와서 '-' 기준으로 split하여 배열(gsSp[3])로 나눔.
    block = gsNumIndex[a].split('-')

    
    # A-23
    if(block[1]=="A" and block[2]=="23"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
           
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
                
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[23]/ins').click()

    # A-22
    elif(block[1]=="A" and block[2]=="22"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[22]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
        time.sleep(1.3)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
            
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
    
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[3]/ul/li[22]/ins').click()

    # B or C 일 경우
    else:
        pass





print(jjlist)
print(prolist)


# 페이지 전환
driver.get('http://210.96.71.85/main/main.do')

# 로그인 페이지가 뜰 때까지 대기
wait = WebDriverWait(driver, 15)
element = wait.until(expected_conditions.element_to_be_clickable((By.ID, "wrap")))

driver.find_element(By.NAME, 'user_id').send_keys('manager')
driver.find_element(By.NAME, 'password').send_keys('manager123')
driver.find_element(By.XPATH, '//*[@id="form-login"]/div[2]').click()


# 상암, 영남 for 선언
for a in range(0, len(gsNumIndex)):

    # gsNum[i]값을 가져와서 '-' 기준으로 split하여 배열(gsSp[3])로 나눔.
    block = gsNumIndex[a].split('-')

    # B-23
    if(block[1]=="B" and block[2]=="23"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[17]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[17]/ul/li[2]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
            
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[17]/ins').click()

    # B-22
    elif(block[1]=="B" and block[2]=="22"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[16]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[16]/ul/li[2]/ins').click()
        time.sleep(1.3)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
    
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[16]/ins').click()

    # C-23
    elif(block[1]=="C" and block[2]=="23"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ul/li[3]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
            
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ins').click()

    # C-22
    elif(block[1]=="C" and block[2]=="22"):

        time.sleep(2)
        print(gsNumIndex[a])
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ul/li[2]/ins').click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "GS시험인증(1등급)" + "')]").click()
        time.sleep(1.3)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + gsNumIndex[a] + "')]").click()
        time.sleep(1)
        driver.find_element(By.XPATH, "//*[contains(text(),'" + "인증관련" + "')]").click()
        time.sleep(1.5)
        try:
            if (driver.find_element(By.CLASS_NAME, "list-no-data").is_displayed()):
                print("확인서 및 등록증이 존재하지 않습니다.")
                jjlist.insert(a,'x')
                prolist.insert(a,'x')
                print(jjlist)
                print(prolist)
                
        except:
                print("확인서 및 등록증이 존재합니다.")
                jjlist.insert(a,'o')
                prolist.insert(a,'o')
                print(jjlist)
                print(prolist)
    
        driver.find_element(By.XPATH, '//*[@id="edm-folder"]/ul/li[4]/ul/li[19]/ins').click()

    # A 일 경우
    else:
        pass





    

gsFrame['저작권 확인서'] = jjlist
gsFrame['프로그램 등록부'] = prolist
        
print(gsFrame)

gsFrame.to_excel(r"C:/Users/이건우/Downloads/GSexcel.xlsx", index=False)

# %%
wb = openpyxl.load_workbook('GSexcel.xlsx')
ws = wb.active

for col in ws.columns:
    max_length = 0
    column = col[0].column
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except TypeError:
            pass
    

# 엑셀 파일 저장
wb.save('example.xlsx')
# Out:
# KeyboardInterrupt

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import openpyxl
import time
import pandas as pd 
from openpyxl.styles import Alignment
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions as expected_conditions

# 페이지 전환

chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
driver = webdriver.Chrome(options=chrome_options)
driver.get('http://210.96.71.85/main/main.do')

# 로그인 페이지가 뜰 때까지 대기
wait = WebDriverWait(driver, 15)
element = wait.until(expected_conditions.element_to_be_clickable((By.ID, "wrap")))

driver.find_element(By.NAME, 'user_id').send_keys('manager')
driver.find_element(By.NAME, 'password').send_keys('manager123')
driver.find_element(By.XPATH, '//*[@id="form-login"]/div[2]').click()


print("hello")
# Out:
# hello
